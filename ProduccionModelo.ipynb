# %% [markdown]
# #**INSTRUCCIONES PRODUCCION DE MODELO (ENTORNO LOCAL)**
# **Ejecutar en terminal de Anaconda los siguientes comandos:**
#
# 1. conda create -n ApiCrop
#
# 2. conda activate ApiCrop
#
# 3. conda install python=3.7
#
# 4. pip install -r requirements.txt
#
# 5. pip install wandb==0.12.17
#
# 6. pip install flask
#
# 7. conda install -c anaconda flask
#
# #FINALMENTE EJECUTAR EL SIGUIENTE COMANDO QUE DIRIJIRA AL EXPLORADOR POR DEFECTO PAR HACER PREDICCIONES EN LA SIGUIENTE INTERFAZ
# 8. streamlit run app.py
#
#
# ![screens.png](data:image/png;base64,...)
#
# **Donde los valores mostrados son representados de la siguiente forma:**
#
# 'Annual Pass'= 1
#
# 'Flex Pass'= 2
#
# 'Monthly Pass'= 3
#
# 'One Day Pass'= 4
#
# 'Testing'= 5
#
# 'Walk-up'= 6
